# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('ATB_EC_MM_sample_regression.csv')

# Print the first few rows of the DataFrame
print(df.head())

# Get some basic statistics about the DataFrame
print(df.describe())

# Check the data types of each column
print(df.dtypes)

# Check for missing values in each column
print(df.isnull().sum())

# Plot histograms of all numeric columns
df.hist(figsize=(10,10))
plt.show()

# Compute pairwise correlations between numeric columns
print(df.corr())
# Out:
#    PartyCode  CreditStatusCode  AccountStatus  HardshipCount  DNPCount  \
# 0  100799312                 2              1              0         7
# 1  101219354                 2              1              1         4
# 2  100758128                15              1              3         0
# 3  100921719                14              1              3         2
# 4  100017556                 7              1              3         2
#
#    DelinqAlert  BadDebtor
# 0            0          0
# 1            1          1
# 2            1          1
# 3            1          1
# 4            0          0
#           PartyCode  CreditStatusCode  AccountStatus  HardshipCount  \
# count  2.260000e+03       2260.000000    2260.000000    2260.000000
# mean   1.007431e+08          8.282743       0.447788       1.765929
# std    3.055756e+05          4.833955       0.497376       1.580533
# min    1.000012e+08          1.000000       0.000000       0.000000
# 25%    1.005359e+08          2.000000       0.000000       0.000000
# 50%    1.008215e+08         10.000000       0.000000       2.000000
# 75%    1.009827e+08         12.000000       1.000000       3.000000
# max    1.012414e+08         19.000000       1.000000       5.000000
#
#           DNPCount  DelinqAlert    BadDebtor
# count  2260.000000  2260.000000  2260.000000
# mean      3.536283     0.288496     0.330973
# std       2.287447     0.453163     0.470668
# min       0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000
# 50%       4.000000     0.000000     0.000000
# 75%       6.000000     1.000000     1.000000
# max       7.000000     1.000000     1.000000
# PartyCode           int64
# CreditStatusCode    int64
# AccountStatus       int64
# HardshipCount       int64
# DNPCount            int64
# DelinqAlert         int64
# BadDebtor           int64
# dtype: object
# PartyCode           0
# CreditStatusCode    0
# AccountStatus       0
# HardshipCount       0
# DNPCount            0
# DelinqAlert         0
# BadDebtor           0
# dtype: int64
#                   PartyCode  CreditStatusCode  AccountStatus  HardshipCount  \
# PartyCode          1.000000          0.019952       0.427728       0.028194
# CreditStatusCode   0.019952          1.000000       0.435045       0.128544
# AccountStatus      0.427728          0.435045       1.000000       0.230245
# HardshipCount      0.028194          0.128544       0.230245       1.000000
# DNPCount          -0.019517          0.003936       0.011393       0.008656
# DelinqAlert        0.307629          0.583743       0.695344       0.159219
# BadDebtor          0.337526          0.657537       0.781074       0.183926
#
#                   DNPCount  DelinqAlert  BadDebtor
# PartyCode        -0.019517     0.307629   0.337526
# CreditStatusCode  0.003936     0.583743   0.657537
# AccountStatus     0.011393     0.695344   0.781074
# HardshipCount     0.008656     0.159219   0.183926
# DNPCount          1.000000    -0.015227  -0.003758
# DelinqAlert      -0.015227     1.000000   0.892875
# BadDebtor        -0.003758     0.892875   1.000000
